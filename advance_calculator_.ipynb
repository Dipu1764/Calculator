# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipu1764/Calculator/blob/main/advance_calculator_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
  while True:
    # Display the menu of options
    print("Select operation:")
    print("1. Addition (+)")
    print("2. Subtraction (-)")
    print("3. Multiplication (*)")
    print("4. Division (/)")
    print("5. Exponent (**)")
    print("6. Square root (sqrt)")
    print("7. Evaluate expression")
    print("8. Exit")

    # Get user input for the operation
    choice = input("Enter choice (1-8): ")

    # Perform the selected operation
    if choice == '1':
      num1 = float(input("Enter first number: "))
      num2 = float(input("Enter second number: "))
      result = num1 + num2
      print(f"{num1} + {num2} = {result}")
    elif choice == '2':
      num1 = float(input("Enter first number: "))
      num2 = float(input("Enter second number: "))
      result = num1 - num2
      print(f"{num1} - {num2} = {result}")
    elif choice == '3':
      num1 = float(input("Enter first number: "))
      num2 = float(input("Enter second number: "))
      result = num1 * num2
      print(f"{num1} * {num2} = {result}")
    elif choice == '4':
      num1 = float(input("Enter first number: "))
      num2 = float(input("Enter second number: "))
      result = num1 / num2
      print(f"{num1} / {num2} = {result}")
    elif choice == '5':
      num1 = float(input("Enter first number: "))
      num2 = float(input("Enter second number: "))
      result = num1 ** num2
      print(f"{num1} ** {num2} = {result}")
    elif choice == '6':
      num = float(input("Enter number: "))
      result = num ** 0.5
      print(f"sqrt({num}) = {result}")
    elif choice == '7':
      expression = input("Enter expression: ")
      result = eval(expression)
      print(f"{expression} = {result}")
    elif choice == '8':
      print("Exiting calculator...")
      break
    else:
      print("Invalid input")

# Call the main function
if __name__ == "__main__":
  main()
# Out:
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 88
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 88
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 88
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 98
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 888
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 565
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 568
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
# Enter choice (1-8): 556
# Invalid input
# Select operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponent (**)
# 6. Square root (sqrt)
# 7. Evaluate expression
# 8. Exit
